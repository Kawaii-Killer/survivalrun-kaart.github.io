# %%
import pandas as pd

# %%
# Create an URL object
url = 'https://www.uvponline.nl/uvponlineU/index.php/uvproot/wedstrijdschema/2023'
# Create object page
df = pd.read_html(url, header=0)

df = df[0]

# %%
# Reguliere expressie om tekst tussen haakjes of ' ONK ' met tekst erachter te extraheren
regex = r'\((.*?)\)|\sONK\s(.*?)$'

# Maak een nieuwe kolom 'Opmerking' en vul deze met de overeenkomende tekst
opmerking = df['Plaats'].str.extract(regex, expand=False).fillna('')
df['Opmerking'] = opmerking[0].combine_first(opmerking[1])

# Zuiver de plaatsnamen door de tekst tussen haakjes of ' ONK ' met tekst erachter te verwijderen
df['Plaats'] = df['Plaats'].str.replace(regex, '', regex=True).str.strip()

# %%
df
# Out:
#          Datum            Plaats Klassement Klassement.1 Klassement.2  \
# 0   16-09-2023          Udenhout        NaN          NaN            K
# 1   17-09-2023          Udenhout          L            M          NaN
# 2   24-09-2023          Enschede        NaN          NaN          NaN
# 3   24-09-2023               Ede        NaN          NaN            K
# 4   01-10-2023        Leeuwarden          L            M            K
# 5   14-10-2023         Boerakker        NaN            M            K
# 6   15-10-2023         Rotterdam        NaN          NaN          NaN
# 7   22-10-2023             Neede        NaN          NaN            K
# 8   29-10-2023             Deest        NaN          NaN            K
# 9   05-11-2023         Groningen        NaN          NaN            K
# 10  11-11-2023        Vollenhove        NaN            M            K
# 11  19-11-2023            Adegem          L            M          NaN
# 12  25-11-2023             Doorn        NaN          NaN            K
# 13  26-11-2023             Doorn          L            M          NaN
# 14  10-12-2023          Enschede        NaN          NaN            K
# 15  17-12-2023         Dinxperlo        NaN          NaN            K
# 16  07-01-2024           Beltrum          L          NaN          NaN
# 17  21-01-2024        Westerbork        NaN            M          NaN
# 18  03-02-2024        Gendringen        NaN          NaN            K
# 19  04-02-2024        Gendringen          L            M          NaN
# 20  11-02-2024            Zwolle        NaN            M            K
# 21  24-02-2024            Losser        NaN          NaN          NaN
# 22  03-03-2024            Wesepe        NaN          NaN          NaN
# 23  03-03-2024       Nieuwehorne        NaN          NaN          NaN
# 24  10-03-2024     Kootstertille        NaN            M            K
# 25  17-03-2024            Zelhem        NaN          NaN          NaN
# 26  24-03-2024             Zeist        NaN          NaN            K
# 27  31-03-2024             Buren        NaN          NaN          NaN
# 28  07-04-2024           Bathmen          L            M          NaN
# 29  14-04-2024              Elst        NaN          NaN            K
# 30  21-04-2024              Norg        NaN          NaN          NaN
# 31  21-04-2024       Steenbergen        NaN            M            K
# 32  21-04-2024           Utrecht        NaN          NaN          NaN
# 33  27-04-2024     Kollumerzwaag        NaN          NaN          NaN
# 34  12-05-2024           Havelte        NaN          NaN            K
# 35  25-05-2024             Delft        NaN          NaN            K
# 36  01-06-2024          De Knipe        NaN          NaN          NaN
# 37  02-06-2024          Nijmegen        NaN          NaN          NaN
# 38  02-06-2024          De Knipe          L            M            K
# 39  08-06-2024         Eindhoven        NaN          NaN          NaN
# 40  09-06-2024           Dronten        NaN          NaN            K
# 41  16-06-2024         Harreveld          L            M            K
# 42  30-06-2024              Loil        NaN          NaN          NaN
# 43  30-06-2024  's-Hertogenbosch        NaN          NaN            K
#
#    Klassement.3 Klassement.4  \
# 0             J          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3             J            B
# 4             J            B
# 5             J            B
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN            B
# 9           NaN          NaN
# 10            J            B
# 11          NaN          NaN
# 12            J            B
# 13          NaN          NaN
# 14          NaN            B
# 15            J          NaN
# 16          NaN          NaN
# 17            J          NaN
# 18            J          NaN
# 19          NaN          NaN
# 20            J            B
# 21          NaN          NaN
# 22          NaN          NaN
# 23            J          NaN
# 24            J            B
# 25          NaN          NaN
# 26            J            B
# 27          NaN          NaN
# 28          NaN          NaN
# 29          NaN            B
# 30          NaN          NaN
# 31            J          NaN
# 32          NaN          NaN
# 33          NaN          NaN
# 34            J            B
# 35          NaN          NaN
# 36            J          NaN
# 37          NaN          NaN
# 38          NaN            B
# 39          NaN            B
# 40            J            B
# 41            J          NaN
# 42          NaN          NaN
# 43            J            B
#
#                                               Kwalif.           Afstanden(km)  \
# 0   KWALIFICATIERUN  Deze survivalrun staat geregi...              5,5 - 7 km
# 1   KWALIFICATIERUN  Deze survivalrun staat geregi...              12 - 18 km
# 2                                                 NaN                5 - 7 km
# 3   KWALIFICATIERUN  Deze survivalrun staat geregi...          4,5 - 7 - 8 km
# 4   KWALIFICATIERUN  Deze survivalrun staat geregi...         5,5 - 8 - 11 km
# 5   KWALIFICATIERUN  Deze survivalrun staat geregi...     4 - 6,5 - 9 - 14 km
# 6   KWALIFICATIERUN  Deze survivalrun staat geregi...                5 - 8 km
# 7   KWALIFICATIERUN  Deze survivalrun staat geregi...               7 - 14 km
# 8   KWALIFICATIERUN  Deze survivalrun staat geregi...                5 - 8 km
# 9   KWALIFICATIERUN  Deze survivalrun staat geregi...          1 - 5,5 - 8 km
# 10  KWALIFICATIERUN  Deze survivalrun staat geregi...           5 - 8 - 12 km
# 11  KWALIFICATIERUN  Deze survivalrun staat geregi...          7 - 10 - 18 km
# 12  KWALIFICATIERUN  Deze survivalrun staat geregi...            5 - 7 - 8 km
# 13  KWALIFICATIERUN  Deze survivalrun staat geregi...          8 - 11 - 18 km
# 14  KWALIFICATIERUN  Deze survivalrun staat geregi...                6 - 9 km
# 15  KWALIFICATIERUN  Deze survivalrun staat geregi...                5 - 7 km
# 16  KWALIFICATIERUN  Deze survivalrun staat geregi...        6,5 - 14 - 22 km
# 17  KWALIFICATIERUN  Deze survivalrun staat geregi...           5 - 9 - 11 km
# 18  KWALIFICATIERUN  Deze survivalrun staat geregi...                5 - 9 km
# 19  KWALIFICATIERUN  Deze survivalrun staat geregi...              14 - 20 km
# 20  KWALIFICATIERUN  Deze survivalrun staat geregi...                5 - 9 km
# 21                                                NaN                    7 km
# 22                                                NaN                5 - 8 km
# 23                                                NaN          5 - 10 - 15 km
# 24  KWALIFICATIERUN  Deze survivalrun staat geregi...           5 - 8 - 11 km
# 25                                                NaN           5,5 en 8,5 km
# 26  KWALIFICATIERUN  Deze survivalrun staat geregi...                5 - 8 km
# 27                                                NaN                5 - 8 km
# 28  KWALIFICATIERUN  Deze survivalrun staat geregi...  6,5 - 9,5 - 12 - 18 km
# 29  KWALIFICATIERUN  Deze survivalrun staat geregi...                5 - 8 km
# 30                                                NaN                5 - 8 km
# 31  KWALIFICATIERUN  Deze survivalrun staat geregi...       6,5 - 8,5 - 12 km
# 32                                                NaN                6 - 9 km
# 33                                                NaN                4 - 8 km
# 34  KWALIFICATIERUN  Deze survivalrun staat geregi...      4,5 - 6,5 - 7,5 km
# 35  KWALIFICATIERUN  Deze survivalrun staat geregi...                6 - 9 km
# 36                                                NaN                    5 km
# 37  KWALIFICATIERUN  Deze survivalrun staat geregi...                5 - 8 km
# 38  KWALIFICATIERUN  Deze survivalrun staat geregi...          7 - 12 - 20 km
# 39  KWALIFICATIERUN  Deze survivalrun staat geregi...                5 - 7 km
# 40  KWALIFICATIERUN  Deze survivalrun staat geregi...                6 - 9 km
# 41  KWALIFICATIERUN  Deze survivalrun staat geregi...      5 - 8 - 14 - 21 km
# 42                                                NaN                    6 km
# 43  KWALIFICATIERUN  Deze survivalrun staat geregi...           5,5 en 8,5 km
#
#      min.leeftijd                            Organisator  \
# 0   vanaf 10 jaar         Stichting Survive and Feelgood
# 1   vanaf 15 jaar         Stichting Survive and Feelgood
# 2    vanaf 6 jaar              Stichting Rutbeeksurvival
# 3    vanaf 6 jaar                   Tuxis Ede's Best Run
# 4    vanaf 8 jaar        Stichting Survivalrun Friesland
# 5    vanaf 6 jaar       Stichting Survivalteam Boerakker
# 6    vanaf 8 jaar                         Outdoor Valley
# 7   vanaf 10 jaar            Stichting Survivalrun Neede
# 8   vanaf 10 jaar            Stichting Survivalrun Deest
# 9    vanaf 6 jaar        Stichting Survivalrun Groningen
# 10   vanaf 8 jaar          Stichting Survival Vollenhove
# 11  vanaf 12 jaar            VZW Survivalrun Meetjesland
# 12   vanaf 8 jaar                  Stichting Hang-On-Run
# 13  vanaf 15 jaar                  Sitchting Hang-On-Run
# 14   vanaf 8 jaar                      D.S.S.V. Tartaros
# 15   vanaf 8 jaar           Stichting Survival Dinxperlo
# 16   vanaf 8 jaar          Stichting Survivalrun Beltrum
# 17  vanaf 10 jaar       Stichting Survivalrun Westerbork
# 18  vanaf 10 jaar          Stichting Survival Gendringen
# 19  vanaf 15 jaar          Stichting Survival Gendringen
# 20   vanaf 6 jaar                                Thorrun
# 21  vanaf 10 jaar                      Dinkelsurvivalrun
# 22   vanaf 8 jaar              Stichting Survival Wesepe
# 23   vanaf 8 jaar                                 U3 Run
# 24   vanaf 8 jaar       Stichting Survival Kootstertille
# 25   vanaf 8 jaar            Survivalgroep Jan in t Touw
# 26   vanaf 8 jaar                  Survivalrun Fit Zeist
# 27   vanaf 8 jaar                      Survivalrun Buren
# 28   vanaf 8 jaar                     Schipbeek Survival
# 29  vanaf 10 jaar       Stichting Survivalrun Lingezegen
# 30   vanaf 8 jaar                       Survivalrun Norg
# 31  vanaf 10 jaar       Survivalrun Diomedon Steenbergen
# 32  vanaf 16 jaar          Stichting Utrecht Survivalrun
# 33   vanaf 9 jaar                               Wrot Run
# 34   vanaf 8 jaar          Stichting Survivalrun Havelte
# 35  vanaf 10 jaar         Stichting SurvivalStrijd Delft
# 36   vanaf 8 jaar            Stichting Survival de Knipe
# 37  vanaf 18 jaar                               NSSV FEL
# 38  vanaf 15 jaar            Stichting Survival de Knipe
# 39  vanaf 16 jaar          All Terrain Outdoor Challenge
# 40   vanaf 8 jaar      Stichting Dronterland Survivalrun
# 41   vanaf 8 jaar           Stichting Survival Harreveld
# 42   vanaf 8 jaar  Stichting Sportieve Activiteiten Loil
# 43   vanaf 8 jaar                 Stichting U-Battle Run
#
#              Inschrijflink  Uitslag Opmerking
# 0        >schrijf hier in<      NaN        za
# 1        >schrijf hier in<      NaN        zo
# 2        >schrijf hier in<      NaN
# 3                      NaN      NaN
# 4   Opent 11-06-2023 19:00      NaN
# 5                      NaN      NaN
# 6                      NaN      NaN
# 7   Opent 02-07-2023 19:00      NaN
# 8   Opent 01-07-2023 18:00      NaN
# 9                      NaN      NaN
# 10                     NaN      NaN
# 11                     NaN      NaN         B
# 12                     NaN      NaN        za
# 13                     NaN      NaN        zo
# 14                     NaN      NaN
# 15                     NaN      NaN
# 16                     NaN      NaN
# 17                     NaN      NaN
# 18                     NaN      NaN        za
# 19                     NaN      NaN        zo
# 20                     NaN      NaN
# 21                     NaN      NaN
# 22                     NaN      NaN
# 23                     NaN      NaN
# 24                     NaN      NaN
# 25                     NaN      NaN
# 26                     NaN      NaN
# 27                     NaN      NaN
# 28                     NaN      NaN
# 29                     NaN      NaN       gld
# 30                     NaN      NaN
# 31                     NaN      NaN
# 32                     NaN      NaN
# 33                     NaN      NaN
# 34                     NaN      NaN
# 35                     NaN      NaN
# 36                     NaN      NaN        za
# 37                     NaN      NaN
# 38                     NaN      NaN        zo
# 39                     NaN      NaN
# 40                     NaN      NaN
# 41                     NaN      NaN
# 42                     NaN      NaN
# 43                     NaN      NaN

# %%
import pandas as pd
from bokeh.io import curdoc, output_file, show
from bokeh.layouts import row, column
from bokeh.models import ColumnDataSource, Slider, Select, TextInput
from bokeh.plotting import figure
from bokeh.transform import factor_cmap
from bokeh.palettes import Category10_4
from bokeh.resources import INLINE

# Voorbeeld DataFrame
data = {
    'Datum': ['16-09-2023'],
    'Plaats': ['Udenhout (za)'],
    'Klassement': [None],
    'Klassement.1': [None],
    'Klassement.2': ['K'],
    'Klassement.3': ['J'],
    'Klassement.4': [None],
    'Kwalif.': ['KWALIFICATIERUN Deze survivalrun staat geregi...'],
    'Afstanden(km)': ['5,5 - 7 km'],
    'min.leeftijd': ['vanaf 10 jaar'],
    'Organisator': ['Stichting Survive and Feelgood']
}

df = pd.DataFrame(data)

# Dataset voor plaats-coördinaten mapping (voorbeeld)
plaats_coordinaten = {
    'Udenhout (za)': (51.6106, 5.1399)  # Voorbeeld coördinaten voor Udenhout (za)
}

# Functie om plaats-coördinaten op te halen
def get_coordinaten(plaats):
    return plaats_coordinaten.get(plaats, (None, None))

# Maak een ColumnDataSource
source = ColumnDataSource(df)

# Maak een figuur voor de kaart
p = figure(width=800, height=400, x_range=(0, 100), y_range=(0, 100), tooltips=[("Plaats", "@Plaats")])
p.circle(x='x', y='y', size=10, color=factor_cmap('Klassement.2', palette=Category10_4, factors=['K', 'J']), legend_field='Klassement.2', source=source)

# Maak sliders voor datum en afstand
datum_slider = Slider(title="Datum", start=0, end=100, step=1, value=0)
afstand_slider = Slider(title="Afstand (km)", start=0, end=10, step=0.5, value=0)

# Maak een selectionbox voor klassement
klassement_select = Select(title="Klassement", options=['K', 'J'], value='K')

# Maak een selectionbox voor kwalificatierun
kwalificatie_select = Select(title="Kwalificatierun", options=[None, 'KWALIFICATIERUN'], value=None)

# Callback functie voor filtering
def update():
    filtered_df = df.copy()
    
    # Filter op datum
    filtered_df = filtered_df[filtered_df['Datum'] == datum_slider.value]
    
    # Filter op afstand
    filtered_df = filtered_df[filtered_df['Afstanden(km)'] == afstand_slider.value]
    
    # Filter op klassement
    filtered_df = filtered_df[filtered_df['Klassement.2'] == klassement_select.value]
    
    # Filter op kwalificatierun
    filtered_df = filtered_df[filtered_df['Kwalif.'] == kwalificatie_select.value]
    
    source.data = ColumnDataSource.from_df(filtered_df)

# Voeg de callbacks toe aan de sliders en selectionbox
for widget in [datum_slider, afstand_slider, klassement_select, kwalificatie_select]:
    widget.on_change('value', lambda attr, old, new: update())

# Initial update
update()

# Plaats de widgets en de figuur in een layout
layout = column(
    row(datum_slider, afstand_slider),
    row(klassement_select, kwalificatie_select),
    p
)

curdoc().add_root(layout)


# Creëer een outputbestand
output_file("bokeh_dashboard.html", title="Bokeh Dashboard")

# Toon het dashboard
show(layout, resources=INLINE)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x" value "x", key "y" value "y" [renderer: GlyphRenderer(id='1303', ...)]
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html
